# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df=pd.read_csv("County_Health_Rankings.csv")
df
# Out:
#        State         County  State code  County code  Year span  \
# 0         US  United States         0.0          0.0  2003-2005
# 1         US  United States         0.0          0.0  2004-2006
# 2         US  United States         0.0          0.0  2005-2007
# 3         US  United States         0.0          0.0  2006-2008
# 4         US  United States         0.0          0.0  2007-2009
# ...      ...            ...         ...          ...        ...
# 303859    WY  Weston County        56.0         45.0       2007
# 303860    WY  Weston County        56.0         45.0       2008
# 303861    WY  Weston County        56.0         45.0       2009
# 303862    WY  Weston County        56.0         45.0       2010
# 303863    WY  Weston County        56.0         45.0       2011
#
#                          Measure name  Measure id    Numerator  Denominator  \
# 0                  Violent crime rate        43.0  1328750.667  274877117.0
# ...

# %%
df.head()
# Out:
#   State         County  State code  County code  Year span  \
# 0    US  United States         0.0          0.0  2003-2005
# 1    US  United States         0.0          0.0  2004-2006
# 2    US  United States         0.0          0.0  2005-2007
# 3    US  United States         0.0          0.0  2006-2008
# 4    US  United States         0.0          0.0  2007-2009
#
#          Measure name  Measure id    Numerator  Denominator   Raw value  \
# 0  Violent crime rate        43.0  1328750.667  274877117.0  483.398066
# 1  Violent crime rate        43.0  1340928.667  277612778.5  483.021233
# 2  Violent crime rate        43.0  1355853.167  280407694.7  483.529230
# 3  Violent crime rate        43.0  1366928.333  287614567.7  475.263942
# 4  Violent crime rate        43.0  1339439.333  292576281.2  457.808585
#
#    Confidence Interval Lower Bound  Confidence Interval Upper Bound  \
# 0                              NaN                              NaN
# ...

# %%
df.tail()
# Out:
#        State         County  State code  County code Year span  \
# 303859    WY  Weston County        56.0         45.0      2007
# 303860    WY  Weston County        56.0         45.0      2008
# 303861    WY  Weston County        56.0         45.0      2009
# 303862    WY  Weston County        56.0         45.0      2010
# 303863    WY  Weston County        56.0         45.0      2011
#
#                          Measure name  Measure id  Numerator  Denominator  \
# 303859  Daily fine particulate matter       125.0        NaN          NaN
# 303860  Daily fine particulate matter       125.0        NaN          NaN
# 303861  Daily fine particulate matter       125.0        NaN          NaN
# 303862  Daily fine particulate matter       125.0        NaN          NaN
# 303863  Daily fine particulate matter       125.0        NaN          NaN
#
#         Raw value  Confidence Interval Lower Bound  \
# 303859       9.37                              NaN
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 303864 entries, 0 to 303863
# Data columns (total 14 columns):
#  #   Column                           Non-Null Count   Dtype
# ---  ------                           --------------   -----
#  0   State                            303858 non-null  object
#  1   County                           303858 non-null  object
#  2   State code                       303860 non-null  float64
#  3   County code                      303860 non-null  float64
#  4   Year span                        303390 non-null  object
#  5   Measure name                     303390 non-null  object
#  6   Measure id                       303390 non-null  float64
#  7   Numerator                        214076 non-null  float64
#  8   Denominator                      184779 non-null  float64
#  9   Raw value                        289956 non-null  float64
#  10  Confidence Interval Lower Bound  189412 non-null  float64
# ...

# %%
df.isnull().sum()
# Out:
# State                                   6
# County                                  6
# State code                              4
# County code                             4
# Year span                             474
# Measure name                          474
# Measure id                            474
# Numerator                           89788
# Denominator                        119085
# Raw value                           13908
# Confidence Interval Lower Bound    114452
# Confidence Interval Upper Bound    114452
# Data Release Year                  153735
# fipscode                             9581
# dtype: int64

# %%
df.fillna(0,inplace=True)

# %%
df.drop_duplicates(inplace=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 297071 entries, 0 to 303863
# Data columns (total 14 columns):
#  #   Column                           Non-Null Count   Dtype
# ---  ------                           --------------   -----
#  0   State                            297071 non-null  object
#  1   County                           297071 non-null  object
#  2   State code                       297071 non-null  float64
#  3   County code                      297071 non-null  float64
#  4   Year span                        297071 non-null  object
#  5   Measure name                     297071 non-null  object
#  6   Measure id                       297071 non-null  float64
#  7   Numerator                        297071 non-null  float64
#  8   Denominator                      297071 non-null  float64
#  9   Raw value                        297071 non-null  float64
#  10  Confidence Interval Lower Bound  297071 non-null  float64
# ...

# %% [markdown]
# ### 1)find out top 5 highest health Ranking by state

# %%
high_rank_by_state =df.groupby('State')['Raw value'].max().sort_values(ascending=False)

top_5_states = high_rank_by_state.head(5)
print(top_5_states)

colors = ['lightgreen', 'salmon', 'gold', 'lightcoral', 'lightblue',]
plt.figure(figsize=(10, 6))
top_5_states.plot(kind='bar', color=colors)
plt.title('Top 5 highest Health Rankings by State')
plt.xlabel('State')
plt.ylabel('Health Ranking')
plt.xticks(rotation=45, ha='right')
plt.tight_layout()
plt.show()
# Out:
# State
# AK    32810.400
# SD    32053.900
# ND    25367.021
# FL    23667.500
# MT    19936.610
# Name: Raw value, dtype: float64

# %% [markdown]
# ### 2)What is average raw value for each year span?

# %%
avg_raw_value=df.groupby('Year span')['Raw value'].mean()
avg1=avg_raw_value.sort_values(ascending=False).head(3)
print("Average Raw value of a specific measures across all ountries and years by",avg1)

plt.figure(figsize=(12,6))
plt.bar(avg1.index,avg1.values,color=['lightgreen','red','pink','purple'],width=0.8,label=avg1.index)
plt.xlabel('Year span')
plt.ylabel('Raw Value')
plt.xticks()
plt.show()
# Out:
# Average Raw value of a specific measures across all ountries and years by Year span
# 1997-1999    7744.172964
# 2002-2004    7736.943533
# 2001-2003    7728.836329
# Name: Raw value, dtype: float64

# %% [markdown]
# ### 3)Which state has the lowest average health ranking?

# %%
avg_health_ranking_by_state = df.groupby('State')['Raw value'].mean().sort_values(ascending=False)
lowest_avg_health_ranking_state = avg_health_ranking_by_state.idxmin()
print("State with the lowest average health ranking:", lowest_avg_health_ranking_state)
# Out:
# State with the lowest average health ranking: PR

# %% [markdown]
# ### 4)find out top 5 highest health Ranking by country

# %%
high_rank =df.groupby('County')['Raw value'].max().sort_values(ascending=False)

top_5_states = high_rank.head(5)
print(top_5_states)

colors = ['lightgreen', 'salmon', 'gold', 'lightcoral', 'lightblue',]
plt.figure(figsize=(10, 6))
top_5_states.plot(kind='bar', color=colors)
plt.title('Top 5 highest Health Rankings by County')
plt.xlabel('County')
plt.ylabel('Health Ranking')
plt.xticks(rotation=45, ha='right')
plt.tight_layout()
plt.show()
# Out:
# County
# Lake and Peninsula Borough    32810.400
# Buffalo County                32053.900
# Mellette County               28433.300
# Shannon County                27344.500
# Sioux County                  25367.021
# Name: Raw value, dtype: float64

# %% [markdown]
# ### 5)find out top 5 highest confidence interval range for specific country?

# %%
max_confidence=df.groupby('County')['Confidence Interval Upper Bound'].max()
avg1=max_confidence.sort_values(ascending=False).head()
print("Top 5 Confidence interval range by",avg1)

plt.figure(figsize=(10,6))
plt.bar(avg1.index,avg1.values,color=['lightgreen','red','pink','salmon', 'gold'],width=0.8,label=avg1.index)
plt.title("Top 5 Confidence interval range by countries")
plt.xlabel('County')
plt.ylabel('Confidence Interval Upper Bound')
plt.xticks()
plt.show()
# Out:
# Top 5 Confidence interval range by County
# Lake and Peninsula Borough    46148.3
# Buffalo County                42793.6
# Mellette County               39465.1
# Corson County                 31173.3
# Shannon County                30854.3
# Name: Confidence Interval Upper Bound, dtype: float64

# %% [markdown]
# ### 6)What is the correlation between health rankings and the numerator/denominator?

# %%
correlation = df[['Raw value', 'Numerator', 'Denominator']].corr()
print("Correlation between health rankings and numerator/denominator:")
print(correlation)
plt.figure(figsize=(10, 6))
sns.heatmap(correlation, annot=True, cmap='coolwarm', fmt=".2f", linewidths=0.5)
plt.title('Correlation between Health Rankings and Numerator/Denominator')
plt.show()
# Out:
# Correlation between health rankings and numerator/denominator:
#              Raw value  Numerator  Denominator
# Raw value     1.000000  -0.007440    -0.008797
# Numerator    -0.007440   1.000000     0.531882
# Denominator  -0.008797   0.531882     1.000000

# %% [markdown]
# ### 7)CalCulate maximum count of top 5 states with specific confidence interval range?

# %%
max_confidence=df.groupby('State')['Confidence Interval Lower Bound'].max()
avg1=max_confidence.sort_values(ascending=False).head(5)
print("Top 5 Confidence interval range by",avg1)

plt.figure(figsize=(10,6))
plt.bar(avg1.index,avg1.values,color=['lightgreen','red','pink','purple','brown'],width=0.8,label=avg1.index)
plt.title("Top 3 Confidence interval range by States")
plt.xlabel('State')
plt.ylabel('Confidence Interval Lower Bound')
plt.xticks()
plt.show()
# Out:
# Top 5 Confidence interval range by State
# SD    23917.100
# AK    22543.200
# FL    20925.600
# ND    20142.917
# MD    17855.600
# Name: Confidence Interval Lower Bound, dtype: float64

# %% [markdown]
# ### 8)Calculate the maximum count of top 2 countries with data release year?

# %%
avg_data_release=df.groupby('County')['Data Release Year'].max()
avg1=avg_data_release.sort_values(ascending=False).head(2)
print("Top 2 data release year for each ",avg1)

plt.figure(figsize=(10,6))
plt.bar(avg1.index,avg1.values,color=['lightgreen','red'],width=0.8,label=avg1.index)
plt.title("Top 2 Data release year for each country")
plt.xlabel('County')
plt.ylabel('Data Release Year')
plt.xticks()
plt.show()
# Out:
# Top 2 data release year for each  County
# Lancaster County    2014.0
# Ontario County      2014.0
# Name: Data Release Year, dtype: float64

# %% [markdown]
# ### 9)Calculate maximum count of bottom 5 fipscode with sepcific country name?

# %%
max_fipscode=df.groupby('County')['fipscode'].max()
avg1=max_fipscode.sort_values(ascending=False).tail(5)
print("Bottom 5 Fipscode with the help of ",avg1)

plt.figure(figsize=(10,6))
plt.bar(avg1.index,avg1.values,color=['lightgreen','red','pink','brown'],width=0.8,label=avg1.index)
plt.title("Bopttom 5 fipscode with the help of country name")
plt.xlabel('County')
plt.ylabel('fipscode')
plt.xticks()
plt.show()
# Out:
# Bottom 5 Fipscode with the help of  County
# Chilton County    1021.0
# Bullock County    1011.0
# Autauga County    1001.0
# Alabama           1000.0
# United States        0.0
# Name: fipscode, dtype: float64

# %% [markdown]
# ### 10)What are the top 5 countries with highest numerator value?

# %%
avg_numerator=df.groupby('County')['Numerator'].max()
avg1=avg_numerator.sort_values(ascending=False).head()
print("Average numerator value of a specific measures across all",avg1)

plt.figure(figsize=(10,6))
plt.bar(avg1.index,avg1.values,color=['lightgreen','red','pink','gold','salmon'],width=0.8,label=avg1.index)
plt.xlabel('County')
plt.ylabel('Numerator')
plt.xticks()
plt.show()
# Out:
# Average numerator value of a specific measures across all County
# United States    62144711.0
# California        6829725.0
# Texas             5854743.0
# Florida           3853392.0
# New York          3552158.0
# Name: Numerator, dtype: float64

# %% [markdown]
# ### 11)What are the top 5 countries with highest Denominator value?

# %%
avg_numerator=df.groupby('County')['Denominator'].max()
avg1=avg_numerator.sort_values(ascending=False).head()
print("Average numerator value of a specific measures across all",avg1)

plt.figure(figsize=(10,6))
plt.bar(avg1.index,avg1.values,color=['lightgreen','red','pink','gold','salmon'],width=0.8,label=avg1.index)
plt.xlabel('County')
plt.ylabel('Denominator')
plt.xticks()
plt.show()
# Out:
# Average numerator value of a specific measures across all County
# United States    602683251.0
# California        37691912.0
# Texas             25674681.0
# New York          19489627.0
# Florida           19057542.0
# Name: Denominator, dtype: float64
